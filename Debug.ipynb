# %%
# %run NeuralNetwork.ipynb
# Out:
# 0 Normalization
# 1 Weights
# 2 Biases
# 3 Activation
# 4 Weights
# 5 Biases
# 6 Activation
# 7 Weights
# 8 Biases
# 9 Activation
# relu activated
# relu activated
# relu activated
# relu activated
# relu activated
# relu activated
# [-1.338490900725463]
